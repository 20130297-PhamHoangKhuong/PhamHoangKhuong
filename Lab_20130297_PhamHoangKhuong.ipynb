# %% [markdown]
# <a href="https://colab.research.google.com/github/20130297-PhamHoangKhuong/PhamHoangKhuong/blob/main/Lab_20130297_PhamHoangKhuong.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab #2
# This lab is the first step to get farmilliar with some common Machine Learning libraries, named ***Pandas*** and ***Matlotlib***.
#
# *   **Deadline: 23:59, 18/03/2024**

# %% [markdown]
# #0. Mount Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd '/content/gdrive/MyDrive/???'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# [Errno 2] No such file or directory: '/content/gdrive/MyDrive/???'
# /content

# %% [markdown]
# #1. Import libraries

# %%
# code
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# #2. Load dataset
#
# *   Load dataset (named ***student-dataset.csv***) using ***read_csv*** from pandas
# *   Then, display 10 last examples

# %%
# code
df = pd.read_csv("/content/gdrive/MyDrive/student-dataset.csv")
df.head(10)
# Out:
#    id              name               nationality gender  ethnic.group  age  \
# 0   0         Kiana Lor                     China      F           NaN   22
# 1   1    Joshua Lonaker  United States of America      M           NaN   22
# 2   2     Dakota Blanco  United States of America      F           NaN   22
# 3   3   Natasha Yarusso  United States of America      F           NaN   20
# 4   4    Brooke Cazares                    Brazil      F           NaN   21
# 5   5  Rochelle Johnson  United States of America      F           NaN   21
# 6   6        Joey Abreu                     China      M           NaN   22
# 7   7    Preston Suarez                    Brazil      M           NaN   22
# 8   8          Lee Dong               Philippines      F           NaN   24
# 9   9     Maa'iz al-Dia                    Turkey      M           NaN   22
#
#    english.grade  math.grade  sciences.grade  language.grade  \
# 0            3.5         3.7             3.1             1.0
# ...

# %% [markdown]
# #3. Show statistics of the given dataset

# %%
# code
df.describe()
# Out:
#                id  ethnic.group         age  english.grade  math.grade  \
# count  307.000000           0.0  307.000000     307.000000  307.000000
# mean   153.000000           NaN   21.964169       3.369707    3.414332
# std     88.767487           NaN    1.248013       0.538724    0.476839
# min      0.000000           NaN   19.000000       1.500000    2.100000
# 25%     76.500000           NaN   21.000000       3.100000    3.100000
# 50%    153.000000           NaN   22.000000       3.500000    3.500000
# 75%    229.500000           NaN   23.000000       3.800000    3.800000
# max    306.000000           NaN   26.000000       4.000000    4.000000
#
#        sciences.grade  language.grade  portfolio.rating  coverletter.rating  \
# count      307.000000      307.000000        307.000000          307.000000
# mean         3.446580        4.396417          3.986971            4.110749
# std          0.509081        0.996474          0.928749            0.823936
# ...

# %% [markdown]
# #4. Sort dataset by ***nationality***

# %%
# code
df.sort_values(by="nationality")
# Out:
#       id                   name               nationality gender  \
# 146  146       Juhaina al-Bilal                Bangladesh      F
# 285  285  Viridiana Ballesteros                    Brazil      F
# 271  271          Jasmine Lopez                    Brazil      F
# 4      4         Brooke Cazares                    Brazil      F
# 96    96         Mateo Cisneros                    Brazil      M
# ..   ...                    ...                       ...    ...
# 147  147           Siena Ingram  United States of America      F
# 149  149        Vincent Webster  United States of America      M
# 151  151         Patrick Carnes  United States of America      M
# 305  305       Eliana Michelsen  United States of America      F
# 153  153          Jenna Whitney  United States of America      F
#
#      ethnic.group  age  english.grade  math.grade  sciences.grade  \
# 146           NaN   20            3.9         3.9             3.9
# ...

# %% [markdown]
# #5. Group dataset by ***nationality*** and ***gender***

# %%
# code
print(df.groupby(['nationality','gender']).groups)
# Out:
# {('Bangladesh', 'F'): [146], ('Brazil', 'F'): [4, 135, 180, 226, 271, 285], ('Brazil', 'M'): [7, 96, 203], ('Canada', 'F'): [111, 139, 293], ('Canada', 'M'): [18, 121, 306], ('Canada', 'other'): [104], ('Chile', 'M'): [211], ('China', 'F'): [0, 162, 189, 218, 232], ('China', 'M'): [6, 21, 24, 61, 76, 176, 194, 214], ('Colombia', 'F'): [183], ('Colombia', 'M'): [94, 185, 244, 283], ('Cuba', 'F'): [70], ('Dominican Republic', 'F'): [29], ('Egypt', 'M'): [150], ('El Salvador', 'F'): [105], ('Germany', 'F'): [128], ('India', 'F'): [35, 41, 72, 175, 198], ('India', 'M'): [172, 215, 259], ('Japan', 'F'): [15, 37, 79, 95, 164, 200, 264, 280], ('Japan', 'M'): [20, 43, 46, 97, 99], ('Korea (Republic of)', 'F'): [68, 251], ('Korea (Republic of)', 'M'): [213], ('Mexico', 'F'): [39, 49, 82, 117, 125, 140, 145, 148, 169, 188, 237, 265, 296], ('Mexico', 'M'): [13, 50, 87, 112, 141, 178, 191, 210, 236, 268], ('Mexico', 'other'): [17], ('Morocco', 'F'): [187], ('Myanmar', 'F'): [85], ('Netherlands',
# ...

# %% [markdown]
# #6. Use scatter plot to represent the relationship between ***age*** and ***refletter.rating***
# Rememer adding titles, xlabel, ylabel, ... to the plot

# %%
# code
# Thêm tiêu đề và nhãn cho biểu đồ
plt.title('Relationship between Age and Refletter Rating')
plt.xlabel('Age')
plt.ylabel('Refletter Rating')
# Tạo biểu đồ scatter plot
plt.scatter(df['age'], df['refletter.rating'], s=30, color="pink", edgecolor='black')
# Hiển thị biểu đồ
plt.show()

# %% [markdown]
# #7. Use scatter plot to represent the relationship between ***age*** and ***sciences.grade***
# Rememer adding titles, xlabel, ylabel, ... to the plot

# %%
#code
# Thêm tiêu đề và nhãn cho biểu đồ
plt.title('Relationship between Age and Sciences Grade')
plt.xlabel('Age')
plt.ylabel('Sciences Grade')
# Tạo biểu đồ scatter plot
plt.scatter(df['age'], df['sciences.grade'], s=30, color="yellow", edgecolor='black')
# Hiển thị biểu đồ
plt.show()

# %% [markdown]
# #8. Use histogram plot to represent the distribution of ***Age***
# using bins=5

# %%
#code
plt.hist(df['age'], bins = 5, color='silver', alpha=0.5, edgecolor='black')
# Hiển thị biểu đồ
plt.show()

# %% [markdown]
# #9. Create a data frame that computes the average of ages in each countries?
#
# Hint: Use groupby, select the age column and aggregate using mean.

# %%
#code
# Tính trung bình tuổi của mỗi quốc gia
average= df.groupby('nationality')['age'].mean()
# Hiển thị kết quả
print(average)
# Out:
# nationality
# Bangladesh                  20.000000
# Brazil                      22.444444
# Canada                      21.285714
# Chile                       21.000000
# China                       21.692308
# Colombia                    21.200000
# Cuba                        21.000000
# Dominican Republic          22.000000
# Egypt                       20.000000
# El Salvador                 23.000000
# Germany                     20.000000
# India                       21.625000
# Japan                       22.384615
# Korea (Republic of)         22.000000
# Mexico                      21.833333
# Morocco                     21.000000
# Myanmar                     22.000000
# Netherlands                 21.000000
# Nicaragua                   24.000000
# Pakistan                    22.333333
# Peru                        22.000000
# Philippines                 24.000000
# Poland                      21.000000
# Russian Federation          22.500000
# ...

# %% [markdown]
# #10. Create a dataframe including average of ***english.grade, math.grade, sciences.grade, language.grade, portfolio.rating, coverletter.rating, refletter.rating*** of each country

# %%
#code
# Tính trung bình các cột theo quốc gia
average = df.groupby('nationality').mean()
# Loại bỏ ba cột 'id', 'ethnic.group', 'age'
average = average.drop(columns=['id', 'ethnic.group', 'age'])
# Hiển thị kết quả
print(average)
# Out:
#                           english.grade  math.grade  sciences.grade  \
# nationality
# Bangladesh                     3.900000    3.900000        3.900000
# Brazil                         3.577778    3.377778        3.055556
# Canada                         3.657143    3.014286        3.600000
# Chile                          3.700000    3.700000        4.000000
# China                          3.253846    3.784615        3.376923
# Colombia                       3.540000    3.580000        3.280000
# Cuba                           3.900000    2.800000        3.200000
# Dominican Republic             3.400000    3.800000        4.000000
# Egypt                          1.500000    3.500000        3.200000
# El Salvador                    3.300000    2.900000        3.500000
# Germany                        3.200000    3.500000        3.900000
# India                          3.000000    3.275000        3.637500
# Japan                          3.330769    3.538462        3.492308
# ...

# %% [markdown]
# #Finally,
# Remember renaming the notebook.
